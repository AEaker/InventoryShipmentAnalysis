# %%
import pandas as pd

# %%
PartCount2 = pd.read_excel("PartCount.xlsx")
#PartCount.drop(PartCount.columns[0], axis=1, inplace"=True)
PartCount2 = PartCount2.iloc[:, [1,2,3,7,8]]
PartCount2 = PartCount2[PartCount2["90 Day Usage"] != 0]
PartCount2["Daily Consumption"] = PartCount2["30 Day Usage"]/30
PartCount2["Daily Consumption"] = PartCount2["Daily Consumption"].astype('int64')
PartCount2
# Out:
#         Part Number                           Description  On Hand  \
# 0        000052120D                     LOGO PUDDLE LIGHT     9065
# 1       000061166 D                    COUPE CARGO BLOCKS   -14465
# 3         000065760                        EXT RNG REMOTE      107
# 4        000065760A                  XTENDED RANGE KEYFOB      315
# 5        000071597D                     PASSAT BWL MY2019      563
# 6        000072548A    GENTEX REAR VIEW MIRROR VERSION: A     2285
# 7        000072548B    GENTEX REAR VIEW MIRROR VERSION: B    22224
# 9        000072548H                   PASSAT PRISM MIRROR      108
# 11      000093059AH               NEW STYLE ROADSIDE KITS     9305
# 14   000093108L 9B9                        FIRST AID KITS     8360
# 27        3C5065110                           LUGGAGE NET     1791
# 28   3CM061166  469                     COUPE TRUNK LINER    15954
# 29        3CM061167                         COUP PRIV CVR     2072
# 30   3CM061370  WGK                         COUP CRPT MAT        0
# 31   3CM061370A WGK                       COUPE MOJO MATS      988
# 32   3CM061530  82V                     COUPE RUBBER MATS     9456
# 33        3CM065760            CXR COUPE REMOTE START KIT      175
# 34        3CM071151                       COUPE CROSSBARS      121
# 35        3CM072195                      COUP HOOD DFLCTR      370
# 36        3CM075101                    COUP SPLSHGRD REAR     1363
# 37        3CM075111                   COUP SPLSHGRD FRONT     1371
# 38        3CM092135            TRAILER HITCH RECEIVER KIT       13
# 41   3CN061166  469                     ATLAS TRUNK LINER    30919
# 42   3CN061167  ZRX                   ATLAS PRIVACY COVER    11510
# 44   3CN061195A DML                       ABA BUMPERDILLO     2306
# 45   3CN061370C WGK                    ATLAS CARPT 7 SEAT        0
# 46   3CN061370D WGK                    ATLAS CARPT 6 SEAT      370
# 47   3CN061370E WGK              ATLAS MOJO MATS 7 SEATER     1447
# 51   3CN061550B 041                   ATLAS 7-SEATER MATS     3064
# 52   3CN061550C 041                    ATLAS 6 SEATER MAT     7074
# 53        3CN065110                     ATLAS LUGGAGE NET      739
# 54        3CN065760                    ATLAS REMOTE START      846
# 57       3CN071151A                       ATLAS ROOF RACK      287
# 58        3CN071597                      ATLAS BWL MY2019     1001
# 60   3CN071691  DML                      ATLAS SIDE STEPS      537
# 66        3CN092730   ATLAS HITCH BALL AND MOUNT 2,000 LB      127
# 67       3CN092730A  ATLAS HITCH BALL AND MOUNT 5,000 LBS     4457
# 70   3CN807521P 9B9             REAR VALANCE (NON R-LINE)       -1
# 75   561061166  469       TRUNK LINER (CARGO)- ANTHRACITE    14497
# 76   561061195  KS6                           BUMPERDILLO     5169
# 78   561061370E EOM              PASSAT CARPET MATS BLACK      346
# 80   561061550E 041                                   BKM      944
# 81       561065760B                                    XX      197
# 108      561075101B                     REAR SPLASH GUARD      180
# 110      561075111A                    FRONT SPLASH GUARD      164
# 127      7L0055305N                 ATLAS 7 PIN CONNECTOR     2818
# 135     N  91079901                             TORX BOLT        2
#
#      30 Day Usage  90 Day Usage  Daily Consumption
# 0            1350          1507                 45
# 1               0          3979                  0
# 3               1             1                  0
# 4             489           773                 16
# 5              45            57                  1
# 6               0             1                  0
# 7            4728         15210                157
# 9              11            12                  0
# 11           2745          9620                 91
# 14           2688          9496                 89
# 27             21            23                  0
# 28           2374          9192                 79
# 29           1446          5307                 48
# 30             26           143                  0
# 31             16            16                  0
# 32           2374          9192                 79
# 33              1             1                  0
# 34             44           109                  1
# 35            136           167                  4
# 36            269           421                  8
# 37            269           421                  8
# 38              0             8                  0
# 41           3549         13462                118
# 42           2206          8762                 73
# 44            609          2044                 20
# 45              0            87                  0
# 46             13            45                  0
# 47             27            31                  0
# 51           1572          4963                 52
# 52           1977          8499                 65
# 53            171           583                  5
# 54             49           138                  1
# 57            145           304                  4
# 58             80           227                  2
# 60            255           491                  8
# 66              0             8                  0
# 67           1638          5775                 54
# 70              0             8                  0
# 75           1364          1880                 45
# 76            989          3125                 32
# 78             34           108                  1
# 80           1364          1880                 45
# 81             14            78                  0
# 108            13            27                  0
# 110            13            27                  0
# 127          1638          5775                 54
# 135             0             8                  0

# %%
ideal = pd.read_excel("Ideal.xlsx")
ideal
# Out:
#        Part Number                           Description  Ideal Max  \
# 0       000052120D                     LOGO PUDDLE LIGHT        NaN
# 1      000061166 D                    COUPE CARGO BLOCKS        NaN
# 2        000065760                        EXT RNG REMOTE        NaN
# 3       000065760A                  XTENDED RANGE KEYFOB        NaN
# 4       000071597D                     PASSAT BWL MY2019        NaN
# 5       000072548A    GENTEX REAR VIEW MIRROR VERSION: A       60.0
# 6       000072548B    GENTEX REAR VIEW MIRROR VERSION: B     5220.0
# 7       000072548H                   PASSAT PRISM MIRROR       60.0
# 8      000093059AH               NEW STYLE ROADSIDE KITS     7272.0
# 9   000093108L 9B9                        FIRST AID KITS     6300.0
# 10       3C5065110                           LUGGAGE NET        NaN
# 11  3CM061166  469                     COUPE TRUNK LINER        NaN
# 12       3CM061167                         COUP PRIV CVR     2196.0
# 13  3CM061370  WGK                         COUP CRPT MAT        NaN
# 14  3CM061370A WGK                       COUPE MOJO MATS        NaN
# 15  3CM061530  82V                     COUPE RUBBER MATS     3840.0
# 16       3CM065760            CXR COUPE REMOTE START KIT        NaN
# 17       3CM071151                       COUPE CROSSBARS      224.0
# 18       3CM072195                      COUP HOOD DFLCTR      180.0
# 19       3CM075101                    COUP SPLSHGRD REAR        NaN
# 20       3CM075111                   COUP SPLSHGRD FRONT        NaN
# 21       3CM092135            TRAILER HITCH RECEIVER KIT        NaN
# 22  3CN061166  469                     ATLAS TRUNK LINER    13560.0
# 23  3CN061167  ZRX                   ATLAS PRIVACY COVER     3360.0
# 24  3CN061195A DML                       ABA BUMPERDILLO        NaN
# 25  3CN061370C WGK                    ATLAS CARPT 7 SEAT        NaN
# 26  3CN061370D WGK                    ATLAS CARPT 6 SEAT        NaN
# 27  3CN061370E WGK              ATLAS MOJO MATS 7 SEATER        NaN
# 28  3CN061550B 041                   ATLAS 7-SEATER MATS     3094.0
# 29  3CN061550C 041                    ATLAS 6 SEATER MAT     3276.0
# 30       3CN065110                     ATLAS LUGGAGE NET        NaN
# 31       3CN065760                    ATLAS REMOTE START        NaN
# 32      3CN071151A                       ATLAS ROOF RACK      252.0
# 33       3CN071597                      ATLAS BWL MY2019        NaN
# 34  3CN071691  DML                      ATLAS SIDE STEPS        NaN
# 35       3CN092730   ATLAS HITCH BALL AND MOUNT 2,000 LB        NaN
# 36      3CN092730A  ATLAS HITCH BALL AND MOUNT 5,000 LBS        NaN
# 37  3CN807521P 9B9             REAR VALANCE (NON R-LINE)        NaN
# 38  561061166  469       TRUNK LINER (CARGO)- ANTHRACITE        NaN
# 39  561061195  KS6                           BUMPERDILLO     2400.0
# 40  561061370E EOM              PASSAT CARPET MATS BLACK        NaN
# 41  561061550E 041                                   BKM        NaN
# 42      561065760B                               BRE KIT      100.0
# 43      561075101B                     REAR SPLASH GUARD        NaN
# 44      561075111A                    FRONT SPLASH GUARD        NaN
# 45      7L0055305N                 ATLAS 7 PIN CONNECTOR        NaN
# 46     N  91079901                             TORX BOLT        NaN
#
#     +10% of Ideal               Comments
# 0             NaN                    TBD
# 1             NaN             Irrelevant
# 2             NaN         Minimal Usage?
# 3             NaN                    TBD
# 4             NaN                    TBD
# 5            70.0                    NaN
# 6          5742.0                    NaN
# 7            70.0                    NaN
# 8          7999.2                    NaN
# 9          6930.0                    NaN
# 10            NaN                    TBD
# 11            NaN  Change to returnable?
# 12         2416.0                    NaN
# 13            NaN               Obsolete
# 14            NaN            Returnable?
# 15         4224.0                    NaN
# 16            NaN         Minimal Usage?
# 17          246.4                    NaN
# 18          198.0                    NaN
# 19            NaN                    TBD
# 20            NaN                    TBD
# 21            NaN                    TBD
# 22        14916.0                    NaN
# 23         3696.0                    NaN
# 24            NaN                    TBD
# 25            NaN                    TBD
# 26            NaN                    TBD
# 27            NaN                    TBD
# 28         3403.4    54 to a returnable?
# 29         3603.6     54 to a returnable
# 30            NaN                    TBD
# 31            NaN                    TBD
# 32          277.2                    NaN
# 33            NaN                    TBD
# 34            NaN                    TBD
# 35            NaN               Obsolete
# 36            NaN                    TBD
# 37            NaN               Obsolete
# 38            NaN               Obsolete
# 39         2640.0                    NaN
# 40            NaN                    TBD
# 41            NaN                    TBD
# 42          110.0                    NaN
# 43            NaN                    TBD
# 44            NaN                    TBD
# 45            NaN                    TBD
# 46            NaN             Irrelevant

# %%
mergedf = pd.merge(PartCount2, ideal, on=["Part Number", "Description"])
mergedf.head()
# Out:
#    Part Number           Description  On Hand  30 Day Usage  90 Day Usage  \
# 0   000052120D     LOGO PUDDLE LIGHT     9065          1350          1507
# 1  000061166 D    COUPE CARGO BLOCKS   -14465             0          3979
# 2    000065760        EXT RNG REMOTE      107             1             1
# 3   000065760A  XTENDED RANGE KEYFOB      315           489           773
# 4   000071597D     PASSAT BWL MY2019      563            45            57
#
#    Daily Consumption  Ideal Max  +10% of Ideal        Comments
# 0                 45        NaN            NaN             TBD
# 1                  0        NaN            NaN      Irrelevant
# 2                  0        NaN            NaN  Minimal Usage?
# 3                 16        NaN            NaN             TBD
# 4                  1        NaN            NaN             TBD

# %%
mergedf = mergedf[(mergedf["Comments"] != "Irrelevant") & (mergedf["Comments"] != "Obsolete")]
mergedf.loc[mergedf["On Hand"] > mergedf["Ideal Max"], "WarehouseCompliance"] = "Overstock"
# mergedf.loc[mergedf["On Hand"] < mergedf["Ideal Max"], "WarehouseCompliance"] = "Understock"
# mergedf.loc[mergedf["On Hand"] < mergedf["Daily Consumption"]*30, "WarehouseCompliance"] = "4 Week Consumption Danger"
mergedf.loc[mergedf["Comments"] == "TBD", "WarehouseCompliance"] = "TBD..."
mergedf["WarehouseCompliance"].fillna("Complaint", inplace=True)
mergedf
# Out:
#   Part Number                         Description  On Hand  30 Day Usage  \
# 0  000052120D                   LOGO PUDDLE LIGHT     9065          1350
# 2   000065760                      EXT RNG REMOTE      107             1
# 3  000065760A                XTENDED RANGE KEYFOB      315           489
# 4  000071597D                   PASSAT BWL MY2019      563            45
# 5  000072548A  GENTEX REAR VIEW MIRROR VERSION: A     2285             0
#
#    90 Day Usage  Daily Consumption  Ideal Max  +10% of Ideal        Comments  \
# 0          1507                 45        NaN            NaN             TBD
# 2             1                  0        NaN            NaN  Minimal Usage?
# 3           773                 16        NaN            NaN             TBD
# 4            57                  1        NaN            NaN             TBD
# 5             1                  0       60.0           70.0             NaN
#
#   WarehouseCompliance
# 0              TBD...
# 2           Complaint
# 3              TBD...
# 4              TBD...
# 5           Overstock

# %%
Forecast = pd.read_excel("Forecast.xlsx", sheet_name="WIP")
Forecast
# Out:
#        KNR Week  KNR Day    Comm         Type  XNR Country Pre     Model  \
# 0             7        1  137347    ATLAS PA1  X9B  Canada      CA22NR
# 1             7        4  154988    ATLAS PA1  X9A     USA      CA24UR
# 2             7        6  154989    ATLAS PA1  X9A     USA      CA25UR
# 3             5        3  GD1038  ATLAS Coupe  X9A     USA      CMC4UR
# 4             6        3  115071    ATLAS PA1  X9A     USA      CA25UR
# ...         ...      ...     ...          ...  ...     ...  ..       ...
# 12723         7        3  172287    ATLAS PA1  X9A     USA      CA27UZ
# 12724         7        3  159473  ATLAS Coupe  X9A     USA      CMC4NR
# 12725         4        4  123099    ATLAS PA1  X9B  Canada      CA24UR
# 12726         7        3  176644    ATLAS PA1  X9A     USA      CA27UR
# 12727         7        3  161549    ATLAS PA1  X9A     USA      CA25UR
#
#       RLine Fuel Label  Antenna             PS Base    Status Region  Dealer  \
# 0      ----       ----      NaN  2R2R-   B4WAA-4L-B  Assigned    VWC  Canada
# 1      ----       ----      NaN  0Q0Q-   B4PAA-6L-B  Assigned    NER  401015
# 2      RLIN       ----      NaN  2R2R-   B4PAA-6L-B  Assigned    NER  401015
# 3      RLIN       ----      NaN  0Q0Q-   C4PAA-6L-C  Assigned    NER  401015
# 4      RLIN       ----      NaN  Q9Q9-   B4PAA-6L-B  Assigned    NER  401015
# ...     ...        ...      ...                 ...       ...    ...     ...
# 12723  ----       ----      NaN  0Q0Q-   B4PFF-6L-B      Bulk    SER  412982
# 12724  ----       ----      NaN  0Q0Q-   C4PAA-4L-C  Assigned    CER  420325
# 12725  ----       ----      NaN  2R2R-   B4PAA-6L-B  Assigned    VWC  Canada
# 12726  ----       ----      NaN  2T2T-   B4WAA-6L-B      Bulk    NER  424999
# 12727  ----       ----      NaN  2R2R-   B4PAA-6L-B  Assigned    NER  408295
#
#          Dest Carrier Type                      Options
# 0      Canada         Rail                          ENG
# 1          70         Rail              AGHAMKAPCBSKCXS
# 2          70         Rail        ABAAGHAMCAPCBSKCXSP04
# 3          70         Rail              AGHBSKCCPCMKCXS
# 4          70         Rail     ABAAGHAMCAPCBSKCXSP04VPL
# ...       ...          ...                          ...
# 12723     TBD          TBD              AMKAPCARVP12P16
# 12724      75         Rail                    CXSVPLZC1
# 12725  Canada         Rail                          BIL
# 12726     TBD          TBD           AGHAMCBSKP04P12VPL
# 12727      74         Rail  ABAAGHAMKAPCARVBSKBWLBXUCXS
#
# [12728 rows x 18 columns]

# %%
import datetime
todaysdate = datetime.date.today()
year, week_num, day_of_week = todaysdate.isocalendar()
todaysnumber = datetime.datetime.today().weekday() + 1
print(todaysnumber, todaysdate, week_num)
# Out:
# 3 2021-02-03 5

# %%
UpdatedForecast = Forecast[(Forecast["KNR Week"] > week_num) & (Forecast["KNR Day"] >= todaysnumber)]
UpdatedForecast.columns
# Out:
# Index(['KNR Week', 'KNR Day', 'Comm', 'Type', 'XNR', 'Country', 'Pre', 'Model',
#        'RLine', 'Fuel Label', 'Antenna', 'PS Base', 'Status', 'Region',
#        'Dealer', 'Dest', 'Carrier Type', 'Options'],
#       dtype='object')

# %%
Allocations = pd.read_excel("Allocations.xlsx")
Allocations
# Out:
#    SVCCD  VWGA
# 0    ABA   122
# 1    ABC    21
# 2    ACC     4
# 3    ACK    13
# 4    AGG   132
# ..   ...   ...
# 71   VPL   449
# 72   ZA1    68
# 73   ZA2    30
# 74   ZA3    98
# 75   ZC1    76
#
# [76 rows x 2 columns]

# %%
ABACount = Allocations.loc[Allocations["SVCCD"] == "ABA", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ABA").sum()
ABACount
# Out:
# 239.0

# %%
AGGCount = Allocations.loc[Allocations["SVCCD"] == "AGG", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("AGG").sum() + Allocations.loc[Allocations["SVCCD"] == "ZA3", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZA3").sum() + Allocations.loc[Allocations["SVCCD"] == "CGG", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("CGG").sum()
ASPGCount
# Out:
# 440.0

# %%
ABCCount = Allocations.loc[Allocations["SVCCD"] == "ABC", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ABC").sum() + Allocations.loc[Allocations["SVCCD"] == "ZA3", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZA3").sum()

# %%
ACCCount =  Allocations.loc[Allocations["SVCCD"] == "ACC", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ACC").sum()
ACKCount =  Allocations.loc[Allocations["SVCCD"] == "ACK", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ACK").sum()
AGHCount =  Allocations.loc[Allocations["SVCCD"] == "AGH", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("AGH").sum()
ALNCount =  Allocations.loc[Allocations["SVCCD"] == "ALN", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ALN").sum()
AMCCount =  Allocations.loc[Allocations["SVCCD"] == "AMC", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("AMC").sum() + Allocations.loc[Allocations["SVCCD"] == "ZA1", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZA1").sum()

# %%
AMKCount =  Allocations.loc[Allocations["SVCCD"] == "AMK", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("AMK").sum() + Allocations.loc[Allocations["SVCCD"] == "ZA2", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZA2").sum()

AtlasTrunkLinerCount = AMKCount + AMCCount

APCCount =  Allocations.loc[Allocations["SVCCD"] == "APC", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("APC").sum() + Allocations.loc[Allocations["SVCCD"] == "ZA1", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZA1").sum() + Allocations.loc[Allocations["SVCCD"] == "ZA2", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZA2").sum()

# %%
B_Mirror_Count =  Allocations.loc[Allocations["SVCCD"] == "ARV", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ARV").sum() + Allocations.loc[Allocations["SVCCD"] == "ZA1", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZA1").sum() + Allocations.loc[Allocations["SVCCD"] == "ZA2", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZA2").sum() + Allocations.loc[Allocations["SVCCD"] == "BRM", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BRM").sum() + Allocations.loc[Allocations["SVCCD"] == "ZC1", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZC1").sum()

# %%
ATHCount = Allocations.loc[Allocations["SVCCD"] == "ATH", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ATH").sum()

ATSCount = Allocations.loc[Allocations["SVCCD"] == "ATS", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ATS").sum() + Allocations.loc[Allocations["SVCCD"] == "ZA3", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZA3").sum()

AWDCount = Allocations.loc[Allocations["SVCCD"] == "AWD", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("AWD").sum() + Allocations.loc[Allocations["SVCCD"] == "CWD", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("CWD").sum()

BDPCount = Allocations.loc[Allocations["SVCCD"] == "BDP", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BDP").sum() + Allocations.loc[Allocations["SVCCD"] == "BLR", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BLR").sum()

BKMCount = Allocations.loc[Allocations["SVCCD"] == "BKM", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BKM").sum()

BLNCount = Allocations.loc[Allocations["SVCCD"] == "BLN", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BLN").sum()

BMJCount = Allocations.loc[Allocations["SVCCD"] == "BMJ", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BMJ").sum()

BRECount = Allocations.loc[Allocations["SVCCD"] == "BRE", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BRE").sum()

RoadsideCount = Allocations.loc[Allocations["SVCCD"] == "BRK", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BRK").sum() + Allocations.loc[Allocations["SVCCD"] == "BSK", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BSK").sum()

FirstAidCount = Allocations.loc[Allocations["SVCCD"] == "FAK", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("FAK").sum() + Allocations.loc[Allocations["SVCCD"] == "BSK", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BSK").sum()

BSGCount =  Allocations.loc[Allocations["SVCCD"] == "BSG", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("BSG").sum()

CBCCount = Allocations.loc[Allocations["SVCCD"] == "CBC", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("CBC").sum()

CCPCount = Allocations.loc[Allocations["SVCCD"] == "CCP", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("CCP").sum() + Allocations.loc[Allocations["SVCCD"] == "ZC1", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("Zc1").sum()

CMCCount = Allocations.loc[Allocations["SVCCD"] == "CMC", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("CMC").sum()

CMKCount = Allocations.loc[Allocations["SVCCD"] == "CMK", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("CMK").sum() + Allocations.loc[Allocations["SVCCD"] == "ZC1", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("ZC1").sum()

PPMCount = Allocations.loc[Allocations["SVCCD"] == "PPM", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("PPM").sum()

VPLCount = Allocations.loc[Allocations["SVCCD"] == "VPL", "VWGA"].iloc[0] + UpdatedForecast["Options"].str.count("VPL").sum()

# %%
# # mergedf = mergedf[(mergedf["Comments"] != "Irrelevant") & (mergedf["Comments"] != "Obsolete")]
# mergedf.loc[mergedf["On Hand"] > mergedf["Ideal Max"], "WarehouseCompliance"] = "Overstock"
# # mergedf.loc[mergedf["On Hand"] < mergedf["Ideal Max"], "WarehouseCompliance"] = "Understock"
# mergedf.loc[mergedf["On Hand"] < mergedf["Daily Consumption"]*30, "WarehouseCompliance"] = "4 Week Consumption Danger"
# mergedf.loc[mergedf["Comments"] == "TBD", "WarehouseCompliance"] = "TBD..."
# mergedf["WarehouseCompliance"].fillna("Complaint", inplace=True)
mergedf.head()
# Out:
#   Part Number                         Description  On Hand  30 Day Usage  \
# 0  000052120D                   LOGO PUDDLE LIGHT     9065          1350
# 2   000065760                      EXT RNG REMOTE      107             1
# 3  000065760A                XTENDED RANGE KEYFOB      315           489
# 4  000071597D                   PASSAT BWL MY2019      563            45
# 5  000072548A  GENTEX REAR VIEW MIRROR VERSION: A     2285             0
#
#    90 Day Usage  Daily Consumption  Ideal Max  +10% of Ideal        Comments  \
# 0          1507                 45        NaN            NaN             TBD
# 2             1                  0        NaN            NaN  Minimal Usage?
# 3           773                 16        NaN            NaN             TBD
# 4            57                  1        NaN            NaN             TBD
# 5             1                  0       60.0           70.0             NaN
#
#   WarehouseCompliance
# 0              TBD...
# 2           Complaint
# 3              TBD...
# 4              TBD...
# 5           Overstock

# %%
mergedf.loc[(mergedf["Part Number"] == "3CN061195A DML") & (mergedf["On Hand"] < ABACount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN061195A DML") & (mergedf["On Hand"] > ABACount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN071151A") & (mergedf["On Hand"] < ABCCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN071151A") & (mergedf["On Hand"] > ABCCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN061370D WGK") & (mergedf["On Hand"] < ACCCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN061370D WGK") & (mergedf["On Hand"] > ACCCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN061370E WGK") & (mergedf["On Hand"] < ACKCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN061370E WGK") & (mergedf["On Hand"] > ACKCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CM075111") & (mergedf["On Hand"] < AGGCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CM075111") & (mergedf["On Hand"] > AGGCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CM075101") & (mergedf["On Hand"] < AGGCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CM075101") & (mergedf["On Hand"] > AGGCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN092730A") & (mergedf["On Hand"] < AGHCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN092730A") & (mergedf["On Hand"] > AGHCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "7L0055305N") & (mergedf["On Hand"] < AGHCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "7L0055305N") & (mergedf["On Hand"] > AGHCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN065110") & (mergedf["On Hand"] < ALNCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN065110") & (mergedf["On Hand"] > ALNCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN061550C 041") & (mergedf["On Hand"] < AMCCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN061550C 041") & (mergedf["On Hand"] > AMCCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN061550B 041") & (mergedf["On Hand"] < AMKCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN061550B 041") & (mergedf["On Hand"] > AMKCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN061166  469") & (mergedf["On Hand"] < AtlasTrunkLinerCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN061166  469") & (mergedf["On Hand"] > AtlasTrunkLinerCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN061167  ZRX") & (mergedf["On Hand"] < APCCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN061167  ZRX") & (mergedf["On Hand"] > APCCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "000072548B") & (mergedf["On Hand"] < B_Mirror_Count), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "000072548B") & (mergedf["On Hand"] > B_Mirror_Count), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CN071691  DML") & (mergedf["On Hand"] < ATSCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CN071691  DML") & (mergedf["On Hand"] > ATSCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CM072195") & (mergedf["On Hand"] < AWDCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CM072195") & (mergedf["On Hand"] > AWDCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "561061195  KS6") & (mergedf["On Hand"] < BDPCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "561061195  KS6") & (mergedf["On Hand"] > BDPCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "561061550E 041") & (mergedf["On Hand"] < BKMCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "561061550E 041") & (mergedf["On Hand"] > BKMCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "561061166  469") & (mergedf["On Hand"] < BKMCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "561061166  469") & (mergedf["On Hand"] > BKMCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3C5065110") & (mergedf["On Hand"] < BLNCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3C5065110") & (mergedf["On Hand"] > BLNCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "5610161370E EOM") & (mergedf["On Hand"] < BMJCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "5610161370E EOM") & (mergedf["On Hand"] > BMJCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "561065760B") & (mergedf["On Hand"] < BRECount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "561065760B") & (mergedf["On Hand"] > BRECount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "000093059AH") & (mergedf["On Hand"] < RoadsideCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "000093059AH") & (mergedf["On Hand"] > RoadsideCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "561075111A") & (mergedf["On Hand"] < BSGCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "561075111A") & (mergedf["On Hand"] > BSGCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "561075101B") & (mergedf["On Hand"] < BSGCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "561075101B") & (mergedf["On Hand"] > BSGCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "000093108L 9B9") & (mergedf["On Hand"] < FirstAidCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "000093108L 9B9") & (mergedf["On Hand"] > FirstAidCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CM071151") & (mergedf["On Hand"] < CBCCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CM071151") & (mergedf["On Hand"] > CBCCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CM061167") & (mergedf["On Hand"] < CCPCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CM061167") & (mergedf["On Hand"] > CCPCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CM061370A WGK") & (mergedf["On Hand"] < CMCCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CM061370A WGK") & (mergedf["On Hand"] > CMCCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CM061530 82V") & (mergedf["On Hand"] < CMKCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CM061530 82V") & (mergedf["On Hand"] > CMKCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "3CM061166 469") & (mergedf["On Hand"] < CMKCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "3CM061166 469") & (mergedf["On Hand"] > CMKCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "000072548H") & (mergedf["On Hand"] < PPMCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "000072548H") & (mergedf["On Hand"] > PPMCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf.loc[(mergedf["Part Number"] == "000052120D") & (mergedf["On Hand"] < VPLCount), "Allocation/Forecast Standing"] = "Less Parts Than Forecasted"
mergedf.loc[(mergedf["Part Number"] == "000052120D") & (mergedf["On Hand"] > VPLCount), "Allocation/Forecast Standing"] = "More Parts Than Forecasted"

mergedf["Allocation/Forecast Standing"].fillna("TBD..",inplace=True)

mergedf
# Out:
#        Part Number                           Description  On Hand  \
# 0       000052120D                     LOGO PUDDLE LIGHT     9065
# 2        000065760                        EXT RNG REMOTE      107
# 3       000065760A                  XTENDED RANGE KEYFOB      315
# 4       000071597D                     PASSAT BWL MY2019      563
# 5       000072548A    GENTEX REAR VIEW MIRROR VERSION: A     2285
# 6       000072548B    GENTEX REAR VIEW MIRROR VERSION: B    22224
# 7       000072548H                   PASSAT PRISM MIRROR      108
# 8      000093059AH               NEW STYLE ROADSIDE KITS     9305
# 9   000093108L 9B9                        FIRST AID KITS     8360
# 10       3C5065110                           LUGGAGE NET     1791
# 11  3CM061166  469                     COUPE TRUNK LINER    15954
# 12       3CM061167                         COUP PRIV CVR     2072
# 14  3CM061370A WGK                       COUPE MOJO MATS      988
# 15  3CM061530  82V                     COUPE RUBBER MATS     9456
# 16       3CM065760            CXR COUPE REMOTE START KIT      175
# 17       3CM071151                       COUPE CROSSBARS      121
# 18       3CM072195                      COUP HOOD DFLCTR      370
# 19       3CM075101                    COUP SPLSHGRD REAR     1363
# 20       3CM075111                   COUP SPLSHGRD FRONT     1371
# 21       3CM092135            TRAILER HITCH RECEIVER KIT       13
# 22  3CN061166  469                     ATLAS TRUNK LINER    30919
# 23  3CN061167  ZRX                   ATLAS PRIVACY COVER    11510
# 24  3CN061195A DML                       ABA BUMPERDILLO     2306
# 25  3CN061370C WGK                    ATLAS CARPT 7 SEAT        0
# 26  3CN061370D WGK                    ATLAS CARPT 6 SEAT      370
# 27  3CN061370E WGK              ATLAS MOJO MATS 7 SEATER     1447
# 28  3CN061550B 041                   ATLAS 7-SEATER MATS     3064
# 29  3CN061550C 041                    ATLAS 6 SEATER MAT     7074
# 30       3CN065110                     ATLAS LUGGAGE NET      739
# 31       3CN065760                    ATLAS REMOTE START      846
# 32      3CN071151A                       ATLAS ROOF RACK      287
# 33       3CN071597                      ATLAS BWL MY2019     1001
# 34  3CN071691  DML                      ATLAS SIDE STEPS      537
# 36      3CN092730A  ATLAS HITCH BALL AND MOUNT 5,000 LBS     4457
# 39  561061195  KS6                           BUMPERDILLO     5169
# 40  561061370E EOM              PASSAT CARPET MATS BLACK      346
# 41  561061550E 041                                   BKM      944
# 42      561075101B                     REAR SPLASH GUARD      180
# 43      561075111A                    FRONT SPLASH GUARD      164
# 44      7L0055305N                 ATLAS 7 PIN CONNECTOR     2818
#
#     30 Day Usage  90 Day Usage  Daily Consumption  Ideal Max  +10% of Ideal  \
# 0           1350          1507                 45        NaN            NaN
# 2              1             1                  0        NaN            NaN
# 3            489           773                 16        NaN            NaN
# 4             45            57                  1        NaN            NaN
# 5              0             1                  0       60.0           70.0
# 6           4728         15210                157     5220.0         5742.0
# 7             11            12                  0       60.0           70.0
# 8           2745          9620                 91     7272.0         7999.2
# 9           2688          9496                 89     6300.0         6930.0
# 10            21            23                  0        NaN            NaN
# 11          2374          9192                 79        NaN            NaN
# 12          1446          5307                 48     2196.0         2416.0
# 14            16            16                  0        NaN            NaN
# 15          2374          9192                 79     3840.0         4224.0
# 16             1             1                  0        NaN            NaN
# 17            44           109                  1      224.0          246.4
# 18           136           167                  4      180.0          198.0
# 19           269           421                  8        NaN            NaN
# 20           269           421                  8        NaN            NaN
# 21             0             8                  0        NaN            NaN
# 22          3549         13462                118    13560.0        14916.0
# 23          2206          8762                 73     3360.0         3696.0
# 24           609          2044                 20        NaN            NaN
# 25             0            87                  0        NaN            NaN
# 26            13            45                  0        NaN            NaN
# 27            27            31                  0        NaN            NaN
# 28          1572          4963                 52     3094.0         3403.4
# 29          1977          8499                 65     3276.0         3603.6
# 30           171           583                  5        NaN            NaN
# 31            49           138                  1        NaN            NaN
# 32           145           304                  4      252.0          277.2
# 33            80           227                  2        NaN            NaN
# 34           255           491                  8        NaN            NaN
# 36          1638          5775                 54        NaN            NaN
# 39           989          3125                 32     2400.0         2640.0
# 40            34           108                  1        NaN            NaN
# 41          1364          1880                 45        NaN            NaN
# 42            13            27                  0        NaN            NaN
# 43            13            27                  0        NaN            NaN
# 44          1638          5775                 54        NaN            NaN
#
#                  Comments WarehouseCompliance Allocation/Forecast Standing
# 0                     TBD              TBD...   More Parts Than Forecasted
# 2          Minimal Usage?           Complaint                        TBD..
# 3                     TBD              TBD...                        TBD..
# 4                     TBD              TBD...                        TBD..
# 5                     NaN           Overstock                        TBD..
# 6                     NaN           Overstock   More Parts Than Forecasted
# 7                     NaN           Overstock   More Parts Than Forecasted
# 8                     NaN           Overstock   More Parts Than Forecasted
# 9                     NaN           Overstock   More Parts Than Forecasted
# 10                    TBD              TBD...   More Parts Than Forecasted
# 11  Change to returnable?           Complaint                        TBD..
# 12                    NaN           Complaint   More Parts Than Forecasted
# 14            Returnable?           Complaint   More Parts Than Forecasted
# 15                    NaN           Overstock                        TBD..
# 16         Minimal Usage?           Complaint                        TBD..
# 17                    NaN           Complaint   More Parts Than Forecasted
# 18                    NaN           Overstock   More Parts Than Forecasted
# 19                    TBD              TBD...   More Parts Than Forecasted
# 20                    TBD              TBD...   More Parts Than Forecasted
# 21                    TBD              TBD...                        TBD..
# 22                    NaN           Overstock   More Parts Than Forecasted
# 23                    NaN           Overstock   More Parts Than Forecasted
# 24                    TBD              TBD...   More Parts Than Forecasted
# 25                    TBD              TBD...                        TBD..
# 26                    TBD              TBD...   More Parts Than Forecasted
# 27                    TBD              TBD...   More Parts Than Forecasted
# 28    54 to a returnable?           Complaint   More Parts Than Forecasted
# 29     54 to a returnable           Overstock   More Parts Than Forecasted
# 30                    TBD              TBD...   More Parts Than Forecasted
# 31                    TBD              TBD...                        TBD..
# 32                    NaN           Overstock   More Parts Than Forecasted
# 33                    TBD              TBD...                        TBD..
# 34                    TBD              TBD...   More Parts Than Forecasted
# 36                    TBD              TBD...   More Parts Than Forecasted
# 39                    NaN           Overstock   More Parts Than Forecasted
# 40                    TBD              TBD...                        TBD..
# 41                    TBD              TBD...   More Parts Than Forecasted
# 42                    TBD              TBD...   More Parts Than Forecasted
# 43                    TBD              TBD...   More Parts Than Forecasted
# 44                    TBD              TBD...   More Parts Than Forecasted

# %%
# mergedf.loc[mergedf["On Hand"] < mergedf["Daily Consumption"]*30, "Estimated Consumption"] = ""
import numpy as np
mergedf["Estimated Supply Life"] = (mergedf["On Hand"]/mergedf["Daily Consumption"])/7
mergedf["Estimated Supply Life"].replace(np.inf, 0, inplace=True)
mergedf["Estimated Supply Life"].fillna(0, inplace=True)
mergedf["Estimated Supply Life"] = mergedf["Estimated Supply Life"].astype(int).astype(str) + " Weeks"
mergedf
# Out:
#        Part Number                           Description  On Hand  \
# 0       000052120D                     LOGO PUDDLE LIGHT     9065
# 2        000065760                        EXT RNG REMOTE      107
# 3       000065760A                  XTENDED RANGE KEYFOB      315
# 4       000071597D                     PASSAT BWL MY2019      563
# 5       000072548A    GENTEX REAR VIEW MIRROR VERSION: A     2285
# 6       000072548B    GENTEX REAR VIEW MIRROR VERSION: B    22224
# 7       000072548H                   PASSAT PRISM MIRROR      108
# 8      000093059AH               NEW STYLE ROADSIDE KITS     9305
# 9   000093108L 9B9                        FIRST AID KITS     8360
# 10       3C5065110                           LUGGAGE NET     1791
# 11  3CM061166  469                     COUPE TRUNK LINER    15954
# 12       3CM061167                         COUP PRIV CVR     2072
# 14  3CM061370A WGK                       COUPE MOJO MATS      988
# 15  3CM061530  82V                     COUPE RUBBER MATS     9456
# 16       3CM065760            CXR COUPE REMOTE START KIT      175
# 17       3CM071151                       COUPE CROSSBARS      121
# 18       3CM072195                      COUP HOOD DFLCTR      370
# 19       3CM075101                    COUP SPLSHGRD REAR     1363
# 20       3CM075111                   COUP SPLSHGRD FRONT     1371
# 21       3CM092135            TRAILER HITCH RECEIVER KIT       13
# 22  3CN061166  469                     ATLAS TRUNK LINER    30919
# 23  3CN061167  ZRX                   ATLAS PRIVACY COVER    11510
# 24  3CN061195A DML                       ABA BUMPERDILLO     2306
# 25  3CN061370C WGK                    ATLAS CARPT 7 SEAT        0
# 26  3CN061370D WGK                    ATLAS CARPT 6 SEAT      370
# 27  3CN061370E WGK              ATLAS MOJO MATS 7 SEATER     1447
# 28  3CN061550B 041                   ATLAS 7-SEATER MATS     3064
# 29  3CN061550C 041                    ATLAS 6 SEATER MAT     7074
# 30       3CN065110                     ATLAS LUGGAGE NET      739
# 31       3CN065760                    ATLAS REMOTE START      846
# 32      3CN071151A                       ATLAS ROOF RACK      287
# 33       3CN071597                      ATLAS BWL MY2019     1001
# 34  3CN071691  DML                      ATLAS SIDE STEPS      537
# 36      3CN092730A  ATLAS HITCH BALL AND MOUNT 5,000 LBS     4457
# 39  561061195  KS6                           BUMPERDILLO     5169
# 40  561061370E EOM              PASSAT CARPET MATS BLACK      346
# 41  561061550E 041                                   BKM      944
# 42      561075101B                     REAR SPLASH GUARD      180
# 43      561075111A                    FRONT SPLASH GUARD      164
# 44      7L0055305N                 ATLAS 7 PIN CONNECTOR     2818
#
#     30 Day Usage  90 Day Usage  Daily Consumption  Ideal Max  +10% of Ideal  \
# 0           1350          1507                 45        NaN            NaN
# 2              1             1                  0        NaN            NaN
# 3            489           773                 16        NaN            NaN
# 4             45            57                  1        NaN            NaN
# 5              0             1                  0       60.0           70.0
# 6           4728         15210                157     5220.0         5742.0
# 7             11            12                  0       60.0           70.0
# 8           2745          9620                 91     7272.0         7999.2
# 9           2688          9496                 89     6300.0         6930.0
# 10            21            23                  0        NaN            NaN
# 11          2374          9192                 79        NaN            NaN
# 12          1446          5307                 48     2196.0         2416.0
# 14            16            16                  0        NaN            NaN
# 15          2374          9192                 79     3840.0         4224.0
# 16             1             1                  0        NaN            NaN
# 17            44           109                  1      224.0          246.4
# 18           136           167                  4      180.0          198.0
# 19           269           421                  8        NaN            NaN
# 20           269           421                  8        NaN            NaN
# 21             0             8                  0        NaN            NaN
# 22          3549         13462                118    13560.0        14916.0
# 23          2206          8762                 73     3360.0         3696.0
# 24           609          2044                 20        NaN            NaN
# 25             0            87                  0        NaN            NaN
# 26            13            45                  0        NaN            NaN
# 27            27            31                  0        NaN            NaN
# 28          1572          4963                 52     3094.0         3403.4
# 29          1977          8499                 65     3276.0         3603.6
# 30           171           583                  5        NaN            NaN
# 31            49           138                  1        NaN            NaN
# 32           145           304                  4      252.0          277.2
# 33            80           227                  2        NaN            NaN
# 34           255           491                  8        NaN            NaN
# 36          1638          5775                 54        NaN            NaN
# 39           989          3125                 32     2400.0         2640.0
# 40            34           108                  1        NaN            NaN
# 41          1364          1880                 45        NaN            NaN
# 42            13            27                  0        NaN            NaN
# 43            13            27                  0        NaN            NaN
# 44          1638          5775                 54        NaN            NaN
#
#                  Comments WarehouseCompliance Allocation/Forecast Standing  \
# 0                     TBD              TBD...   More Parts Than Forecasted
# 2          Minimal Usage?           Complaint                        TBD..
# 3                     TBD              TBD...                        TBD..
# 4                     TBD              TBD...                        TBD..
# 5                     NaN           Overstock                        TBD..
# 6                     NaN           Overstock   More Parts Than Forecasted
# 7                     NaN           Overstock   More Parts Than Forecasted
# 8                     NaN           Overstock   More Parts Than Forecasted
# 9                     NaN           Overstock   More Parts Than Forecasted
# 10                    TBD              TBD...   More Parts Than Forecasted
# 11  Change to returnable?           Complaint                        TBD..
# 12                    NaN           Complaint   More Parts Than Forecasted
# 14            Returnable?           Complaint   More Parts Than Forecasted
# 15                    NaN           Overstock                        TBD..
# 16         Minimal Usage?           Complaint                        TBD..
# 17                    NaN           Complaint   More Parts Than Forecasted
# 18                    NaN           Overstock   More Parts Than Forecasted
# 19                    TBD              TBD...   More Parts Than Forecasted
# 20                    TBD              TBD...   More Parts Than Forecasted
# 21                    TBD              TBD...                        TBD..
# 22                    NaN           Overstock   More Parts Than Forecasted
# 23                    NaN           Overstock   More Parts Than Forecasted
# 24                    TBD              TBD...   More Parts Than Forecasted
# 25                    TBD              TBD...                        TBD..
# 26                    TBD              TBD...   More Parts Than Forecasted
# 27                    TBD              TBD...   More Parts Than Forecasted
# 28    54 to a returnable?           Complaint   More Parts Than Forecasted
# 29     54 to a returnable           Overstock   More Parts Than Forecasted
# 30                    TBD              TBD...   More Parts Than Forecasted
# 31                    TBD              TBD...                        TBD..
# 32                    NaN           Overstock   More Parts Than Forecasted
# 33                    TBD              TBD...                        TBD..
# 34                    TBD              TBD...   More Parts Than Forecasted
# 36                    TBD              TBD...   More Parts Than Forecasted
# 39                    NaN           Overstock   More Parts Than Forecasted
# 40                    TBD              TBD...                        TBD..
# 41                    TBD              TBD...   More Parts Than Forecasted
# 42                    TBD              TBD...   More Parts Than Forecasted
# 43                    TBD              TBD...   More Parts Than Forecasted
# 44                    TBD              TBD...   More Parts Than Forecasted
#
#    Estimated Supply Life
# 0               28 Weeks
# 2                0 Weeks
# 3                2 Weeks
# 4               80 Weeks
# 5                0 Weeks
# 6               20 Weeks
# 7                0 Weeks
# 8               14 Weeks
# 9               13 Weeks
# 10               0 Weeks
# 11              28 Weeks
# 12               6 Weeks
# 14               0 Weeks
# 15              17 Weeks
# 16               0 Weeks
# 17              17 Weeks
# 18              13 Weeks
# 19              24 Weeks
# 20              24 Weeks
# 21               0 Weeks
# 22              37 Weeks
# 23              22 Weeks
# 24              16 Weeks
# 25               0 Weeks
# 26               0 Weeks
# 27               0 Weeks
# 28               8 Weeks
# 29              15 Weeks
# 30              21 Weeks
# 31             120 Weeks
# 32              10 Weeks
# 33              71 Weeks
# 34               9 Weeks
# 36              11 Weeks
# 39              23 Weeks
# 40              49 Weeks
# 41               2 Weeks
# 42               0 Weeks
# 43               0 Weeks
# 44               7 Weeks
